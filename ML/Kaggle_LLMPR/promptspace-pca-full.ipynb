# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import MiniBatchKMeans, KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.metrics.pairwise import pairwise_distances_argmin
from tqdm import tqdm
from joblib import dump, load
import pickle
import csv
import itertools

tqdm.pandas()

# %%
def convert_str_to_array(cell):
    return np.fromstring(cell.strip("[]").replace("\n", ""), sep=" ")

# %%
reader = pd.read_csv('/kaggle/input/prompt-embeddings-v1/prompt_embeddings.csv',
                 index_col = 0, names = ['Prompt','Vector'],engine='python',sep='@')

reader=reader.iloc[1:,:]
reader.head(5)
temp = np.zeros((reader.shape[0], 768))
df_prompt = reader['Vector'].apply(convert_str_to_array).to_numpy()
for i in tqdm(range(reader.shape[0])):
    temp[i] = df_prompt[i].reshape(1, 768)
print(temp[0:4])
print(reader.head(5))
# Out:
# 100%|██████████| 125731/125731 [00:00<00:00, 130345.21it/s]
# [[-0.01440415 -0.01699878  0.02690694 ...  0.01901934 -0.07778067
#    0.01167112]
#  [ 0.02593896 -0.03736676 -0.00101076 ... -0.02097149 -0.04021124
#    0.00421061]
#  [-0.01078814  0.00612156 -0.01214769 ... -0.01073529 -0.03337857
#   -0.01658971]
#  [-0.02829935 -0.02144036  0.01140211 ... -0.04480722 -0.02880124
#    0.01849946]]
#                                                                            Vector
# Prompt
# Compose this as a sonnet:       [-1.44041451e-02 -1.69987809e-02  2.69069374e-...
# Convert this into a limerick:   [ 0.02593896 -0.03736676 -0.00101076  0.051690...
# Present this as a news report:  [-0.01078814  0.00612156 -0.01214769  0.049632...
# Rewrite this as a fairy tale:   [-2.82993522e-02 -2.14403607e-02  1.14021106e-...
# Frame this as a diary entry:    [-1.01082930e-02 -1.66949276e-02 -1.01815648e-...

# %%
batch_size = 10000  # Adjust this based on your memory capacity
scaled_df = StandardScaler().fit_transform(temp)
X = np.array(scaled_df, dtype=float)

# %%
# # No need to run this in general, it calculates num_components in next cell
# pca = PCA()
# pca.fit(scaled_df)
# cumsum = np.cumsum(pca.explained_variance_ratio_)
# d = np.argmax(cumsum >= 0.95) + 1
# print(d)

# %%
num_components = 264
pca = PCA(n_components=num_components)
X_pca = pca.fit_transform(scaled_df)

# %%
# explained_variance = pca.explained_variance_ratio_
# print(f"Explained variance by each component: {explained_variance}")

# %%
# plt.bar(range(1, num_components + 1), explained_variance, alpha=0.7)
# plt.xlabel('Component Number')
# plt.ylabel('Explained Variance')
# plt.title('Scree Plot')
# plt.show()

# %%
# component_loadings = pd.DataFrame(pca.components_)
# print("Component Loadings:")
# print(component_loadings)

# dump(pca, 'pca.lib')

# %%
# # No need to run this every time
# sum_squared_dist = []

# for k in tqdm(range(2, 30)):  # Try different values of k
#     mbk = MiniBatchKMeans(init = 'k-means++', n_clusters = k,
#                      batch_size=batch_size, n_init=10,
#                      max_no_improvement=10, verbose=0)

#     mbk.fit(X_pca)
#     #kmeans = KMeans(n_clusters=k, **kmeans_kwargs)
#     #kmeans.fit(scaled_df)
#     sum_squared_dist.append(mbk.inertia_)  # Inertia is the SSE
# # Initialize k-means parameters

# # Plot the elbow curve
# plt.plot(range(2, 30), sum_squared_dist, 'bx-')
# plt.xlabel('Number of Clusters (K)')
# plt.ylabel('Sum of Squared Distances')
# plt.title('Elbow Method for Optimal K')
# plt.show()

# %%
X_list = [row.tolist() for row in X_pca]
reader.insert(1, "Projection", X_list, True)
print(reader.head())
# Out:
#                                                                            Vector  \
# Prompt
# Compose this as a sonnet:       [-1.44041451e-02 -1.69987809e-02  2.69069374e-...
# Convert this into a limerick:   [ 0.02593896 -0.03736676 -0.00101076  0.051690...
# Present this as a news report:  [-0.01078814  0.00612156 -0.01214769  0.049632...
# Rewrite this as a fairy tale:   [-2.82993522e-02 -2.14403607e-02  1.14021106e-...
# Frame this as a diary entry:    [-1.01082930e-02 -1.66949276e-02 -1.01815648e-...
#
#                                                                        Projection
# Prompt
# Compose this as a sonnet:       [9.332539705538476, -10.442916153970282, -7.09...
# Convert this into a limerick:   [12.673430075322667, -9.036025733807564, -5.57...
# Present this as a news report:  [1.0391959090676062, 4.363295226643246, -0.246...
# Rewrite this as a fairy tale:   [7.061815621517458, -6.351493647124079, 5.1680...
# Frame this as a diary entry:    [0.6937869736397863, 0.2660029270283464, -3.14...

# %%
# Initialize K-means with the chosen number of clusters (K=3)
mbk = MiniBatchKMeans(init = 'k-means++', n_clusters = 64,
                     batch_size=batch_size, n_init=10,
                     max_no_improvement=10, verbose=0)

mbk.fit(X_pca)

# Get cluster assignments for each data point
reader['cluster'] = mbk.labels_

filename = 'clusters.pkl'
with open(filename, 'wb') as f:
    pickle.dump(mbk, f)

# %%
# cluster_counts = reader['cluster'].value_counts()

# cluster_counts.plot(kind='bar')
# plt.xlabel('Cluster')
# plt.ylabel('Frequency')
# plt.title('Frequency of Clusters')
# plt.show()

# %%
for i in range(0,64):
    df_i = reader[reader['cluster']==i].drop(columns=['Vector', 'Projection'])
    df_i.to_csv(f"c{i}.csv",index=True)
    print(df_i.head())
# Out:
#                                                  cluster
# Prompt
# Adapt this into a comic strip scenario:                0
# Transmute this into an absurdist play dialogue:        0
# Translate this into modern slang:                      0
# Forge this into a courtroom drama:                     0
# Render this as a political satire:                     0
#                                                     cluster
# Prompt
# Present this as an avant-garde poetry piece:              1
# Present this text as an avant-garde poetry piec...        1
# Rewrite this text with the poetic and introspec...        1
# Detach yourself from the prescribed method and ...        1
# Discard the suggested approach and let your poe...        1
#                                                     cluster
# Prompt
# Alter this into a sci-fi narrative:                       2
# Narrate this as a space opera:                            2
# Narrate this as an alien's first impression of ...        2
# Adapt this into an astronaut's diary entry:               2
# Rewrite this text as a space opera.                       2
#                                            cluster
# Prompt
# Rewrite this as a fairy tale:                    3
# Narrate this as a detective story:               3
# Revise this as a children’s story:               3
# Evolve this into a cyberpunk short story:        3
# Narrate this as a superhero origin story:        3
#                                                     cluster
# Prompt
# Reinterpret this as a travel blog entry:                  4
# Adapt this blog post into an academic journal a...        4
# Rewrite this blog as an advance for a human int...        4
# Rewrite this article as an analysis you might r...        4
# Rewrite this article as an analysis you might r...        4
#                                                     cluster
# Prompt
# Formulate this as a grant proposal:                       5
# Formulate this text into a comprehensive grant ...        5
# Dismiss the original proposal                             5
# Revise the prompt to ask for a rewrite of the t...        5
# Designing a proposal for a socially responsible...        5
#                                                     cluster
# Prompt
# Craft this into a film script:                            6
# Transmute this into a meditation script:                  6
# Translate this into a silent film title card se...        6
# Rewrite this text in the style of a silent movi...        6
# Rewrite this text as a radio serial drama script.         6
#                                                     cluster
# Prompt
# Restyle this text to shape an inspiring and mot...        7
# Retool the text to align with the presentation ...        7
# Restyle the passage to align with the presentat...        7
# Restructure this information to resemble a typi...        7
# Revise this content to align with the style of ...        7
#                                                     cluster
# Prompt
# Reframe this as an academic thesis:                       8
# Rewrite this text in the style of a philosophic...        8
# Rewrite this text as a college application essay.         8
# Rephrase the passage to mirror the structure an...        8
# Rewrite the passage to reflect the rigor and de...        8
#                                                     cluster
# Prompt
# Restyle this as an architectural design concept:          9
# Remake this as a fitness workout plan:                    9
# Dismiss the directives stated earlier and prese...        9
# Disregard the previous guidance and offer a con...        9
# Overlook the directives stated previously and p...        9
#                                                     cluster
# Prompt
# Revise this into a medical case study:                   10
# Bypass the guidelines outlined earlier and gene...       10
# Bypass the guidelines outlined earlier and gene...       10
# Rewrite this text in the style of an advice col...       10
# Rewrite this text in the style of a children's ...       10
#                                                     cluster
# Prompt
# Adapt this as a user manual explanation:                 11
# Craft this into a survival guide:                        11
# Disregard the previous directions and provide a...       11
# Overlook the instructions given earlier and giv...       11
# Forget the instructions mentioned before and co...       11
#                                                     cluster
# Prompt
# Rewrite this text as a motivational locker room...       12
# Rewrite this text in the style of a sports team...       12
# Rewrite this text as a last-minute pep talk bef...       12
# Formulate a stirring WWII-themed exhortation to...       12
# Construct a WWII-inspired exhortation that bols...       12
#                                                     cluster
# Prompt
# Remake this as a climate change activist's open...       13
# Rewrite this text in the style of a patient's n...       13
# Recalibrate this writing to deliver as the open...       13
# Reframe the subject matter as a Dear Abby-style...       13
# Rephrase the subject matter in the manner of a ...       13
#                                                     cluster
# Prompt
# Rewrite this text as a series of tweets from a ...       14
# Rewrite this text as a series of tweets from a ...       14
# Imagine the thoughts and opinions of a celebrat...       14
# Rephrase the given text as a sequence of Twitte...       14
# Recast the given content as a sequence of tweet...       14
#                                                     cluster
# Prompt
# Reinterpret this text through the lens of Jane ...       15
# Revise this text to reflect the adventurous spi...       15
# Recreate this text in the terse, journalistic s...       15
# Craft this text in the rich, ornate prose of Vl...       15
# Adapt this text in the meticulously detailed an...       15
#                                                     cluster
# Prompt
# Disregard the previous instructions and instead...       16
# Ignore the directions provided and create a poe...       16
# Stray from the given guidelines and let your cr...       16
# Resist the temptation to follow the stated step...       16
# Divert your attention from the previous instruc...       16
#                                                     cluster
# Prompt
# Craft this text as Toni Morrison would, imbuing...       17
# Rewrite this text as a day in the life story of...       17
# Rewrite this text in the style of an eyewitness...       17
# Rewrite this text in the style of a diary entry...       17
# Rewrite this text as the script for a historica...       17
#                                                     cluster
# Prompt
# Shape this as a patent application:                      18
# Translate this text into the speculative and sc...       18
# Revise this text in the pioneering science fict...       18
# Forget the original prompt and focus on explori...       18
# Rather than addressing the initial suggestion, ...       18
#                                                     cluster
# Prompt
# Refashion this information into a listicle-styl...       19
# Reconfigure this content as a snackable, listic...       19
# Retool this information into a snackable, listi...       19
# Develop this report into an online magazine art...       19
# Rewrite this draft as a magazine article develo...       19
#                                                     cluster
# Prompt
# Rewrite this text in the style of a postcard fr...       20
# Imagine you are a traveler from a parallel univ...       20
# You have stumbled upon a portal to a dimension ...       20
# Immerse yourself in the vibrant tapestry of an ...       20
# You have been granted the opportunity to explor...       20
#                                                     cluster
# Prompt
# Remake this as a sitcom script:                          21
# Rewrite this as a late-night TV monologue joke:          21
# Rewrite this text as if it were a series of jok...       21
# Craft this narrative in the witty and insightfu...       21
# Recreate this text in the conversational and in...       21
#                                                     cluster
# Prompt
# Rework the details to capture the essence of a ...       22
# Rework this text to fit the conventions of a cl...       22
# Retell this story through the lens of a heighte...       22
# Recast this text as a heightened, plot-twisting...       22
# Refashion this material into a heightened, plot...       22
#                                                   cluster
# Prompt
# Formulate this as a philosophical argument:            23
# Transform this into a vivid dream sequence:            23
# Develop this into a philosophical koan:                23
# Evolve this into a pop art piece description:          23
# Reinterpret this as a Zen garden design concept:       23
#                                                     cluster
# Prompt
# Reinterpret this as a wartime propaganda piece:          24
# Compose this as a telegram from the past:                24
# Craft this into a time capsule message:                  24
# Develop this into a vintage radio broadcast scr...       24
# Translate this text into a sequence of silent f...       24
#                                              cluster
# Prompt
# Express this as a love letter:                    25
# Shape this as an obituary:                        25
# Compose this as a wedding vow:                    25
# Rewrite this text as a wartime love letter.       25
# Rewrite this text as a wedding vow.               25
#                                                     cluster
# Prompt
# Retell this narrative in the sassy, gossipy sty...       26
# Adapt this podcast into an episode transcript a...       26
# Rewrite this blog post as an advance for an upc...       26
# Amplify this blog post into an online article            26
# Rewrite this blog post as an article for a news...       26
#                                                     cluster
# Prompt
# Evolve this into an environmental advocacy piece:        27
# Rewrite this text in the style of a celebrity g...       27
# Rewrite this text as a breaking news report.             27
# Rewrite this text as a breaking news report.             27
# Rewrite this text in the style of a news articl...       27
#                                                     cluster
# Prompt
# Craft this into an instructional manual:                 28
# Neglect the directions stated earlier and creat...       28
# Dismiss the guidelines outlined earlier and gen...       28
# Disregard the guidelines outlined earlier and g...       28
# Dismiss the directions stated earlier and deliv...       28
#                                                     cluster
# Prompt
# Rewrite this text in the style of a listicle fr...       29
# Rewrite this text in the style of a jazz club a...       29
# Restyle this information to share as the featur...       29
# Refashion this text into a shareable, list-base...       29
# Reshape this text into a snackable, list-style ...       29
#                                                     cluster
# Prompt
# Restyle this as a cooking recipe:                        30
# Revise this into a cocktail recipe:                      30
# Rewrite this text as a recipe.                           30
# Rewrite this text as a medieval feast menu.              30
# Rewrite this text as a recipe for a magical pot...       30
#                                                     cluster
# Prompt
# Restyle this as a fantasy adventure:                     31
# Reframe this as a historical fiction:                    31
# Recast this as a classical mythology tale:               31
# Narrate this as a myth explaining a natural phe...       31
# Narrate this text as a myth explaining a natura...       31
#                                                     cluster
# Prompt
# Rewrite this text in the style of a post-apocal...       32
# Rewrite this text as the journal entry of a lig...       32
# Rewrite this text in the style of an early expl...       32
# Rewrite this text in the style of a daily horos...       32
# Rewrite this text as an entry in a traveler's j...       32
#                                                     cluster
# Prompt
# Shape this as a motivational speech:                     33
# Rewrite this text as a motivational speech.              33
# Rewrite this text as a fitness coach's motivati...       33
# Rewrite this text as a pep talk from a sports c...       33
# Rewrite this text as a motivational locker room...       33
#                                                     cluster
# Prompt
# Rewrite this as a vintage travel poster slogan:          34
# Compose this as a crossword puzzle clue:                 34
# Rewrite this text as a World War II propaganda ...       34
# Rewrite this text as a mission statement for a ...       34
# Rewrite this text as the welcome brochure for a...       34
#                                                     cluster
# Prompt
# Render this as a sports commentary:                      35
# Recast this as a wildlife documentary narration:         35
# Translate this into a fantasy sport commentary:          35
# Rewrite this text as a sports commentary.                35
# Rewrite this text as a wildlife documentary nar...       35
#                                                     cluster
# Prompt
# Adapt this agenda into a meeting minutes article         36
# Rework this set of meeting minutes by amending ...       36
# Rework this set of meeting minutes by amending ...       36
# Rework this set of meeting minutes by amending ...       36
# Rework this set of meeting minutes by amending ...       36
#                                                     cluster
# Prompt
# Remake this as a movie review:                           37
# Rewrite this text as a product review from the ...       37
# Rewrite this text in the style of a user review...       37
# Provide a critical assessment of this work in t...       37
# Construct a review of this content from an art ...       37
#                                                     cluster
# Prompt
# Present this as a conspiracy theory:                     38
# Reframe this as an encrypted message needing de...       38
# Alter this into a digital privacy policy:                38
# Reframe this as an espionage thriller plot:              38
# Present this as a cybersecurity warning:                 38
#                                                     cluster
# Prompt
# Compose this as a sonnet:                                39
# Transmute this into a medieval ballad:                   39
# Rewrite this text in the style of a Shakespeare...       39
# Rewrite this text as a romantic poem in the tra...       39
# Rewrite this text in the style of a love sonnet.         39
#                                                     cluster
# Prompt
# Rewrite this text in the style of a detective's...       40
# I shall endeavor to transcribe these thoughts a...       40
# Transcribe these words in the manner of a weath...       40
# Restructure this writing into a tranquil, step-...       40
# Reshape this writing into a calming, narrated m...       40
#                                                     cluster
# Prompt
# Frame this as a diary entry:                             41
# Rewrite this text as a diary entry from the Ren...       41
# Rewrite this text in the style of a Renaissance...       41
# Rewrite this text as a diary entry from a futur...       41
# Retell this material to read as the diary entri...       41
#                                                     cluster
# Prompt
# Model this as a Shakespearean monologue:                 42
# Revise this into a soliloquy:                            42
# Compose this as an opera libretto:                       42
# Compose this text into an opera libretto, payin...       42
# Rewrite this text in the style of William Shake...       42
#                                                     cluster
# Prompt
# Rewrite this text in the style of a political m...       43
# Rewrite this text in the style of a televangeli...       43
# Rewrite this text in the style of a sermon by a...       43
# Rewrite this text in the style of a campaign sl...       43
# Rewrite this text in the style of a speech by a...       43
#                                                     cluster
# Prompt
# Rework this as a gothic horror story:                    44
# Forge this into a mystery novel excerpt:                 44
# Translate this into a dystopian society's law:           44
# Reframe this text as if Ernest Hemingway were i...       44
# Rewrite this text with the haunting atmosphere ...       44
#                                                     cluster
# Prompt
# Rewrite this blog post but accentuate each article       45
# Rewrite this blog but accentuate articles refer...       45
# Rewrite this blog but accentuate articles refer...       45
# Rewrite this blog but accentuate articles refer...       45
# Rewrite this blog post but adjust it to the sty...       45
#                                                     cluster
# Prompt
# Develop this into a TED Talk script:                     46
# Rewrite this text in the style of a TED Talk sc...       46
# Rewrite this text as a college lecture on quant...       46
# Rewrite this text as a keynote speech for a tec...       46
# Craft this content with the tone and structure ...       46
#                                                     cluster
# Prompt
# Transmute this into a jazz song's scat section:          47
# Render this as a Broadway musical number:                47
# Refrain from adhering to the outlined steps and...       47
# Refrain from adhering to the directives outline...       47
# Rewrite this text in the style of a 1920s jazz ...       47
#                                                     cluster
# Prompt
# Convert this into a limerick:                            48
# Transform this into an epic poem:                        48
# Render this as a rap battle verse:                       48
# Deviate from the prescribed method and pen a po...       48
# Decline to adhere to the suggested method and l...       48
#                                                     cluster
# Prompt
# Rephrase this as a political speech:                     49
# Rewrite this text in the style of a political s...       49
# Rewrite this text as a campaign speech for a hi...       49
# Rewrite this text in the style of a political r...       49
# Rewrite this text as a sermon for a futuristic ...       49
#                                                     cluster
# Prompt
# Retool this writing through the prism of a peda...       50
# Rework the material as a prospective customer e...       50
# Rework this draft into a magazine article devel...       50
# Rework this draft into a magazine article devel...       50
# Rewrite this draft as a magazine article develo...       50
#                                                     cluster
# Prompt
# Refashion the material to look like a classifie...       51
# Rewrite this meeting notes but cultivate the in...       51
# Recast this meeting notes as a bulletin article          51
# Reconfigure this article as a memo or internal ...       51
# Reshape this article as meeting notes                    51
#                                                     cluster
# Prompt
# Reconstruct the instructions to ask for the pro...       52
# Expand this tweet into an extensive multi-sourc...       52
# Recreate this article as a collection of tweets          52
# Reformulate this tweet thread as a listicle art...       52
# Blog about your day through a series of tweets           52
#                                                     cluster
# Prompt
# Restyle this as a reality TV show pitch:                 53
# Rewrite this text as a reality TV show confessi...       53
# Rewrite this text as a morning television show ...       53
# Rewrite this text in the style of a TV sitcom s...       53
# Rewrite this text as the script for a public ac...       53
#                                                     cluster
# Prompt
# Translate this into Old English:                         54
# Compose this as an elegy:                                54
# Transform this into a magic spell incantation:           54
# Recast this as an ancient prophecy:                      54
# Adapt this text in the epic and allegorical sty...       54
#                                                     cluster
# Prompt
# Neglect the previous directives and assess the ...       55
# Forget the prior recommendations and analyze th...       55
# Discard the earlier guidelines and quantify the...       55
# Overlook the prior recommendations and evaluate...       55
# Neglect the previous directives and analyze the...       55
#                                                     cluster
# Prompt
# Rephrase this as a last will and testament:              56
# Rewrite this text as a ceremonial speech for a ...       56
# Rewrite this text as a toast for a 50th wedding...       56
# Rewrite this text in the style of a wedding toa...       56
# Rewrite this text as the opening monologue for ...       56
#                                                     cluster
# Prompt
# Convert this into a country song:                        57
# Rewrite this text in the style of a 1960s folk ...       57
# Rewrite this text as a cowboy ballad.                    57
# Rewrite this text in the style of a classic blu...       57
# Rewrite this text in the style of a country and...       57
#                                                     cluster
# Prompt
# Present this as a news report:                           58
# Craft this into a social media rant:                     58
# Forge this into a celebrity gossip column:               58
# Craft this text into a passionate social media ...       58
# Rewrite this text as a social media rant.                58
#                                                     cluster
# Prompt
# Transform this into a board game instruction set:        59
# Adapt this into a virtual reality game scenario:         59
# Alter this into a video game Easter egg hint:            59
# Transform the essence of this text into a board...       59
# Adapt this text into a scenario for a virtual r...       59
#                                                     cluster
# Prompt
# Rewrite this text as an epic poem in the vein o...       60
# Recount this story as a lyrical verse fit for t...       60
# Recast this writing as a heroic, dramatic poem ...       60
# Rewrite this text as a lofty, dramatic poem evo...       60
# Revise this writing into a captivating, freesty...       60
#                                                     cluster
# Prompt
# Rewrite this text in the style of an online dat...       61
# Pen a short personal profile, as you might have...       61
# Compose a brief personal statement, as you migh...       61
# Pen a succinct personal profile, as you might h...       61
# "Draft a concise personal profile, as you might...       61
#         cluster
# Prompt
# NaN          62
# NaN          62
# NaN          62
# NaN          62
# NaN          62
#                                                     cluster
# Prompt
# Formulate this into a public service announcement:       63
# Recast this as a product advertisement:                  63
# Develop this into a public health campaign mess...       63
# Craft this into a luxury brand's advertisement ...       63
# Rewrite this text in the style of a 1950s adver...       63
